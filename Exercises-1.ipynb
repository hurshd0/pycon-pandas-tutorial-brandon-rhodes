# %%
# %matplotlib inline
import pandas as pd

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
titles = pd.read_csv('data/titles.csv', index_col=None, encoding='utf-8')
titles.head()
# Out:
#                         title  year
# 0  En busca del huevo perdido  1982
# 1                  Blood Loss  2008
# 2                Anjo do Lodo  1951
# 3                     Jaws 19  2015
# 4              Lost in Abroad  2012

# %%
cast = pd.read_csv('data/cast.csv', index_col=None, encoding='utf-8')
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
t = titles

# %%
len(t)
# Out:
# 244914

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
t.sort_values('year').head(2)
# Out:
#                      title  year
# 199177          Miss Jerry  1894
# 169761  The Startled Lover  1898

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
rs = t[t.title == 'Hamlet']
rs
# Out:
#          title  year
# 15005   Hamlet  1990
# 28251   Hamlet  2015
# 31739   Hamlet  1910
# 45507   Hamlet  1954
# 83780   Hamlet  1973
# 85222   Hamlet  1964
# 85679   Hamlet  1987
# 90213   Hamlet  2016
# 106995  Hamlet  2011
# 118162  Hamlet  2000
# 128187  Hamlet  1948
# 142239  Hamlet  1911
# 172269  Hamlet  1913
# 208072  Hamlet  2009
# 208870  Hamlet  1969
# 209772  Hamlet  1996
# 214106  Hamlet  1976
# 216036  Hamlet  1921
# 216743  Hamlet  2017
# 235581  Hamlet  2014

# %%
len(rs)
# Out:
# 20

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
rs = t[t.title == 'North by Northwest']
rs
# Out:
#                      title  year
# 227962  North by Northwest  1959

# %%
len(rs)
# Out:
# 1

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
rs = t[t.title == 'Hamlet'].sort_values('year')
rs.head(1)
# Out:
#         title  year
# 31739  Hamlet  1910

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
rs = t[t.title == 'Treasure Island'].sort_values('year')
rs
# Out:
#                   title  year
# 132692  Treasure Island  1918
# 36690   Treasure Island  1920
# 157538  Treasure Island  1934
# 182528  Treasure Island  1950
# 200877  Treasure Island  1972
# 69495   Treasure Island  1973
# 188811  Treasure Island  1985
# 244365  Treasure Island  1999

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
rs = t[t.year == 1950]
len(rs)
# Out:
# 1113

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
rs = t[t.year == 1960]
len(rs)
# Out:
# 1549

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
rs = t[(t.year >= 1950) & (t.year <= 1959)]
len(rs)
# Out:
# 12934

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
rs = t[t.title == "Batman"]
rs
# Out:
#          title  year
# 132984  Batman  1989
# 237151  Batman  1943

# %%
rs['year']
# Out:
# 132984    1989
# 237151    1943
# Name: year, dtype: int64

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
c = cast
rs = c[c.title == 'Inception']
rs.head()
# Out:
#             title  year                  name   type              character  \
# 98153   Inception  2010  Michael (III) August  actor          LAX Passenger
# 149008  Inception  2010          Peter Basham  actor  Fischer's Jet Captain
# 183937  Inception  2010          Tom Berenger  actor               Browning
# 197877  Inception  2010              Ken Bhan  actor       Mombasan Gambler
# 260128  Inception  2010        Virgile Bramly  actor         Bridge Sub Con
#
#            n
# 98153    NaN
# 149008  44.0
# 183937   8.0
# 197877   NaN
# 260128  29.0

# %%
len(rs)
# Out:
# 78

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
rs = c[c.title == 'Inception']
rs = rs[rs.n.isnull()]
rs.head()
# Out:
#             title  year                  name   type         character   n
# 98153   Inception  2010  Michael (III) August  actor     LAX Passenger NaN
# 197877  Inception  2010              Ken Bhan  actor  Mombasan Gambler NaN
# 374661  Inception  2010         John Ceallach  actor     LAX Passenger NaN
# 497161  Inception  2010          Garvin Cross  actor    Snow Commander NaN
# 684098  Inception  2010         Seve Esposito  actor   Italian Gambler NaN

# %%
len(rs)
# Out:
# 27

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
rs = c[c.title == 'Inception']
rs = rs[rs.n.notnull()]
rs.head()
# Out:
#             title  year            name   type              character     n
# 149008  Inception  2010    Peter Basham  actor  Fischer's Jet Captain  44.0
# 183937  Inception  2010    Tom Berenger  actor               Browning   8.0
# 260128  Inception  2010  Virgile Bramly  actor         Bridge Sub Con  29.0
# 326745  Inception  2010   Michael Caine  actor                  Miles  11.0
# 333415  Inception  2010    Earl Cameron  actor       Elderly Bald Man  20.0

# %%
len(rs)
# Out:
# 51

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
rs = c[c.title == 'North by Northwest']
rs = rs[rs.n.notnull()].sort_values('n')
rs
# Out:
#                       title  year                  name     type  \
# 871426   North by Northwest  1959            Cary Grant    actor
# 3518333  North by Northwest  1959       Eva Marie Saint  actress
# 1457165  North by Northwest  1959           James Mason    actor
# 3157232  North by Northwest  1959   Jessie Royce Landis  actress
# 356707   North by Northwest  1959        Leo G. Carroll    actor
# 3048272  North by Northwest  1959  Josephine Hutchinson  actress
# 1695173  North by Northwest  1959           Philip Ober    actor
# 1275337  North by Northwest  1959         Martin Landau    actor
# 2447081  North by Northwest  1959         Adam Williams    actor
# 1811387  North by Northwest  1959          Edward Platt    actor
# 665768   North by Northwest  1959     Robert Ellenstein    actor
# 2295714  North by Northwest  1959          Les Tremayne    actor
# 464736   North by Northwest  1959       Philip Coolidge    actor
# ...

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
rs = c[(c.title == 'Sleuth') & (c.year == 1972)]
rs.sort_values('n')
# Out:
#           title  year                name     type  \
# 1705394  Sleuth  1972    Laurence Olivier    actor
# 326773   Sleuth  1972       Michael Caine    actor
# 373876   Sleuth  1972      Alec Cawthorne    actor
# 1465483  Sleuth  1972  John (II) Matthews    actor
# 2724553  Sleuth  1972  Eve (III) Channing  actress
# 1448690  Sleuth  1972        Teddy Martin    actor
#
#                           character    n
# 1705394                 Andrew Wyke  1.0
# 326773                  Milo Tindle  2.0
# 373876            Inspector Doppler  3.0
# 1465483  Detective Sergeant Tarrant  4.0
# 2724553             Marguerite Wyke  5.0
# 1448690      Police Constable Higgs  6.0

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
rs = c[(c.title == 'Sleuth') & (c.year == 2007)]
rs.sort_values('n')
# Out:
#           title  year                 name     type          character    n
# 326774   Sleuth  2007        Michael Caine    actor             Andrew  1.0
# 1293634  Sleuth  2007             Jude Law    actor               Milo  2.0
# 1805907  Sleuth  2007        Harold Pinter    actor        Man on T.V.  3.0
# 260242   Sleuth  2007      Kenneth Branagh    actor  Other Man on T.V.  NaN
# 373877   Sleuth  2007  Alec (II) Cawthorne    actor  Inspector Doppler  NaN
# 2724552  Sleuth  2007    Eve (II) Channing  actress    Marguerite Wyke  NaN
# 3370424  Sleuth  2007    Carmel O'Sullivan  actress             Maggie  NaN

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
rs = c[(c.title == 'Hamlet') & (c.year == 1921)]
rs
# Out:
#           title  year                    name     type         character    n
# 7789     Hamlet  1921        Fritz Achterberg    actor       Fortinbras,  9.0
# 458904   Hamlet  1921            Paul Conradi    actor      K?nig Hamlet  2.0
# 555034   Hamlet  1921        Anton De Verdier    actor           Laertes  7.0
# 1135279  Hamlet  1921         Hans Junkermann    actor          Polonius  6.0
# 2185558  Hamlet  1921            Heinz Stieda    actor           Horatio  5.0
# 2375993  Hamlet  1921  Eduard von Winterstein    actor          Claudius  4.0
# 2664423  Hamlet  1921         Mathilde Brandt  actress  K?nigin Gertrude  3.0
# 3062023  Hamlet  1921          Lilly Jacobson  actress           Ophelia  8.0
# 3355176  Hamlet  1921            Asta Nielsen  actress            Hamlet  1.0

# %%
len(rs)
# Out:
# 9

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
rs = c[(c.title == 'Hamlet') & (c.year == 1996)]
len(rs)
# Out:
# 54

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
rs = c[c.character == 'Hamlet']
len(rs)
# Out:
# 96

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
rs = c[c.character == 'Ophelia']
rs[rs.name.duplicated()]
# Out:
#                     title  year             name     type character     n
# 2614868          Virginia  1941   Louise Beavers  actress   Ophelia  10.0
# 3182770  New Blood Rising  2014  Vanessa Leonard  actress   Ophelia   3.0

# %%
len(rs['name'].unique())
# Out:
# 115

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
rs = c[c.character == "The Dude"]
rs
# Out:
#                                   title  year                  name   type  \
# 272161                 The Big Lebowski  1998          Jeff Bridges  actor
# 339389               Terms & Conditions  2015           Jordan Cann  actor
# 498660                         Stranger  2000         Scott Crowell  actor
# 570128           Pizza Man vs. the Dude  2004        Chris DeMarcus  actor
# 610791                      Sweepstakes  1931           Mike Donlin  actor
# 629473                    Self Helpless  2010        Devin The Dude  actor
# 855976                A Few Brains More  2012    Michael D. Goodwin  actor
# 1089444  Jay and Silent Bob Strike Back  2001   Matthew (XIX) James  actor
# 1138933                   Explicit Ills  2008    Christopher Kadish  actor
# 1367230                 American Idiots  2013      Jason Loughridge  actor
# 1386561             The Winds of Autumn  1976           Steve Lyons  actor
# ...

# %%
len(rs)
# Out:
# 19

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
rs = c[c.character == 'The Stranger']
rs.head()
# Out:
#                           title  year                       name   type  \
# 25954                     Theeb  2014  Hassan Mutlag Al-Maraiyeh  actor
# 35748            My Time to Die  2014       Vincent H. Alexander  actor
# 46418                    Hickok  2017               Terral Altom  actor
# 67421                  Get Mean  1975               Tony Anthony  actor
# 67424  Lo straniero di silenzio  1968               Tony Anthony  actor
#
#           character    n
# 25954  The Stranger  2.0
# 35748  The Stranger  2.0
# 46418  The Stranger  NaN
# 67421  The Stranger  1.0
# 67424  The Stranger  1.0

# %%
len(rs)
# Out:
# 212

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %%
rs = c[c.name == 'Sidney Poitier']
rs.head()
# Out:
#                          title  year            name   type  \
# 1816209        A Patch of Blue  1965  Sidney Poitier  actor
# 1816210  A Piece of the Action  1977  Sidney Poitier  actor
# 1816211    A Raisin in the Sun  1961  Sidney Poitier  actor
# 1816212        A Warm December  1973  Sidney Poitier  actor
# 1816213      All the Young Men  1960  Sidney Poitier  actor
#
#                   character    n
# 1816209        Gordon Ralfe  1.0
# 1816210       Manny Durrell  1.0
# 1816211  Walter Lee Younger  1.0
# 1816212    Dr. Matt Younger  1.0
# 1816213   Sgt. Eddie Towler  2.0

# %%
rs[rs.character.duplicated()]
# Out:
#                               title  year            name   type  \
# 1816245            The Organization  1971  Sidney Poitier  actor
# 1816248  They Call Me Mister Tibbs!  1970  Sidney Poitier  actor
#
#             character    n
# 1816245  Virgil Tibbs  1.0
# 1816248  Virgil Tibbs  1.0

# %%
len(rs.character)
# Out:
# 43

# %%
len(rs.character.unique())
# Out:
# 41

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
rs = c[c.name == 'Judi Dench']
rs.head()
# Out:
#                              title  year        name     type  \
# 2814206      84 Charing Cross Road  1987  Judi Dench  actress
# 2814207          A Handful of Dust  1988  Judi Dench  actress
# 2814208  A Midsummer Night's Dream  1968  Judi Dench  actress
# 2814209         A Room with a View  1985  Judi Dench  actress
# 2814210          A Study in Terror  1965  Judi Dench  actress
#
#                           character     n
# 2814206                   Nora Doel   3.0
# 2814207                 Mrs. Beaver  13.0
# 2814208                     Titania  16.0
# 2814209  Eleanor Lavish, a novelist   7.0
# 2814210                       Sally   8.0

# %%
rs[rs.character.duplicated()]
# Out:
#                                          title  year        name     type  \
# 2814216                        Die Another Day  2002  Judi Dench  actress
# 2814219                              GoldenEye  1995  Judi Dench  actress
# 2814240                      Quantum of Solace  2008  Judi Dench  actress
# 2814245                                Skyfall  2012  Judi Dench  actress
# 2814246                                Spectre  2015  Judi Dench  actress
# 2814253  The Second Best Exotic Marigold Hotel  2015  Judi Dench  actress
# 2814256                The World Is Not Enough  1999  Judi Dench  actress
# 2814257                    Tomorrow Never Dies  1997  Judi Dench  actress
# 2814259                       Victoria & Abdul  2017  Judi Dench  actress
#
#                  character    n
# 2814216                  M  6.0
# 2814219                  M  6.0
# 2814240                  M  4.0
# 2814245                  M  2.0
# 2814246                  M  NaN
# ...

# %%
len(rs.character)
# Out:
# 55

# %%
len(rs.character.unique())
# Out:
# 46

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
rs = c[(c.name == 'Cary Grant') & (c.n == 2)]

# %%
rs = rs[rs.year // 10 * 10 == 1940]
rs.sort_values('year')
# Out:
#                    title  year        name   type    character    n
# 871423  My Favorite Wife  1940  Cary Grant  actor   Nick Arden  2.0
# 871433    Penny Serenade  1941  Cary Grant  actor  Roger Adams  2.0

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
rs = c[(c.name == 'Cary Grant') & (c.n == 1)]
rs = rs[rs.year // 10 * 10 == 1940]
rs.sort_values('year')
# Out:
#                                        title  year        name   type  \
# 871448               The Howards of Virginia  1940  Cary Grant  actor
# 871407                       His Girl Friday  1940  Cary Grant  actor
# 871450                The Philadelphia Story  1940  Cary Grant  actor
# 871438                             Suspicion  1941  Cary Grant  actor
# 871452                  The Talk of the Town  1942  Cary Grant  actor
# 871429                 Once Upon a Honeymoon  1942  Cary Grant  actor
# 871398                     Destination Tokyo  1943  Cary Grant  actor
# 871422                             Mr. Lucky  1943  Cary Grant  actor
# 871430                      Once Upon a Time  1944  Cary Grant  actor
# 871390                  Arsenic and Old Lace  1944  Cary Grant  actor
# 871425             None But the Lonely Heart  1944  Cary Grant  actor
# 871424                         Night and Day  1946  Cary Grant  actor
# ...

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %%
rs = c[c.year // 10 * 10 == 1950]
rs = rs[rs.type == 'actor']
rs.head()
# Out:
#                     title  year                  name   type       character  \
# 66        Fire Down Below  1957  'Stretch' Cox Troupe  actor  Limbo Dance by
# 68     Dorp aan de rivier  1958         Frans 't Hoen  actor        Dirk Jan
# 111  Ci sposeremo a Capri  1956         Quartetto 2+2  actor      Themselves
# 119        Die Todesarena  1953      Die 3 Motorellos  actor      Themselves
# 288      Palletoori Pilla  1950        Subba Rao A.V.  actor   Kampanna Dora
#
#         n
# 66   20.0
# 68   15.0
# 111  19.0
# 119   NaN
# 288   4.0

# %%
rs[rs.character.duplicated()].head()
# Out:
#                        title  year              name   type   character   n
# 119           Die Todesarena  1953  Die 3 Motorellos  actor  Themselves NaN
# 398  Hans Christian Andersen  1952         Lee Aaker  actor  Little Boy NaN
# 404              My Son John  1952         Lee Aaker  actor         Boy NaN
# 408     Ride Clear of Diablo  1954         Lee Aaker  actor         Boy NaN
# 499                   Miriam  1957     Yrj? Aaltonen  actor         Boy NaN

# %%
len(rs)
# Out:
# 157738

# %%
len(rs.character.unique())
# Out:
# 93369

# %% [markdown]
# ### How many roles were available for actresses in the 1950s?

# %%
rs = c[c.year // 10 * 10 == 1950]
rs = rs[rs.type == 'actress']
rs.head()
# Out:
#                           title  year               name     type  \
# 2532684  A Woman of Distinction  1950  Lucienne & Ashour  actress
# 2532686         Chain Lightning  1950  Lucienne & Ashour  actress
# 2532693    De moedige bruidegom  1952     Hilda 't Seyen  actress
# 2532730       Cuban Rebel Girls  1959    Beverly Aadland  actress
# 2532731     Death of a Salesman  1951    Beverly Aadland  actress
#
#                      character    n
# 2532684         Apache Dancers  NaN
# 2532686         Apache Dancers  NaN
# 2532693  De moeder van Tinneke  NaN
# 2532730          Beverly Woods  2.0
# 2532731                   Girl  NaN

# %%
rs[rs.character.duplicated()].head()
# Out:
#                                title  year               name     type  \
# 2532686              Chain Lightning  1950  Lucienne & Ashour  actress
# 2533429     Love Is Better Than Ever  1952       Nancy Abbate  actress
# 2533430      The Farmer Takes a Wife  1953       Nancy Abbate  actress
# 2533561                Copper Canyon  1950     Dorothy Abbott  actress
# 2533566  Gunfight at the O.K. Corral  1957     Dorothy Abbott  actress
#
#               character   n
# 2532686  Apache Dancers NaN
# 2533429     Little Girl NaN
# 2533430     Little Girl NaN
# 2533561        Showgirl NaN
# 2533566            Girl NaN

# %%
len(rs)
# Out:
# 57733

# %%
len(rs.character.unique())
# Out:
# 36266

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
rs = c[(c.n == 1) & (c.year <= 1980)]
rs.head()
# Out:
#                       title  year         name   type           character    n
# 300            En glad gutt  1932   Hauk Aabel  actor       Ola Nordistua  1.0
# 305       En herre med bart  1942    Per Aabel  actor  Ole Grong, advokat  1.0
# 1087  Batman Fights Dracula  1967  Jing Abalos  actor              Batman  1.0
# 1088  Batman Fights Dracula  1967  Jing Abalos  actor         Bruce Wayne  1.0
# 1092            Mighty Rock  1969  Jing Abalos  actor         Mighty Rock  1.0

# %%
# Total leading roles w/ duplicates
len(rs)
# Out:
# 65140

# %%
# Duplicate leading roles
rs[rs.character.duplicated()].head()
# Out:
#                          title  year                 name   type  \
# 2013   Buck Privates Come Home  1947           Bud Abbott  actor
# 7411      El rey de la pistola  1962  Miguel Aceves Mej?a  actor
# 7416           Los fanfarrones  1960  Miguel Aceves Mej?a  actor
# 9512     Smoky Mountain Melody  1948            Roy Acuff  actor
# 12987         O.K. Yevtushenko  1968            Tom Adams  actor
#
#               character    n
# 2013      Slicker Smith  1.0
# 7411   Comisario Miguel  1.0
# 7416             Miguel  1.0
# 9512          Roy Acuff  1.0
# 12987      Charles Vine  1.0

# %%
# Total leading roles w/o duplicates
len(rs.character.unique())
# Out:
# 52152

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %%
rs = c[(c.n != 1) & (c.year <= 1980)]
rs.head()
# Out:
#                                        title  year                   name  \
# 20                            Natas es Satan  1977  Ramon 'Cartucho' Pena
# 26                              Los tarantos  1963             'El Guisa'
# 28                              Los tarantos  1963              'El Viti'
# 35  Been Down So Long It Looks Like Up to Me  1971         Murray the 'K'
# 36                    I Wanna Hold Your Hand  1978         Murray the 'K'
#
#      type         character     n
# 20  actor  Nigth Club Owner   NaN
# 26  actor           Bailaor  25.0
# 28  actor           Cantaor  20.0
# 35  actor           Himself   NaN
# 36  actor           Himself  48.0

# %%
# Total non-leading roles w/ duplicates
len(rs)
# Out:
# 1117667

# %%
# Total non-leading roles w/o duplicates
len(rs.character.unique())
# Out:
# 569572

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
c = cast
rs = c[c.year <= 1980]
rs = rs[rs.n.isnull()]
rs.head()
# Out:
#                                         title  year                      name  \
# 20                             Natas es Satan  1977     Ramon 'Cartucho' Pena
# 35   Been Down So Long It Looks Like Up to Me  1971            Murray the 'K'
# 113                         Atemlos vor Liebe  1970              Ballett 2000
# 116                       Thunder in Carolina  1960  2nd Marine Division Band
# 119                            Die Todesarena  1953          Die 3 Motorellos
#
#       type         character   n
# 20   actor  Nigth Club Owner NaN
# 35   actor           Himself NaN
# 113  actor        Themselves NaN
# 116  actor        Themselves NaN
# 119  actor        Themselves NaN

# %%
rs.n.value_counts(dropna=False)
# Out:
# NaN    448347
# Name: n, dtype: int64

# %%
# Total misc. roles w/ duplicates
len(rs)
# Out:
# 448347

# %%
# Total misc. roles w/ duplicates
len(rs.character.unique())
# Out:
# 190694

# %% [markdown]
# ## Scratch Pad

# %%
titles.head(8)
# Out:
#                            title  year
# 0     En busca del huevo perdido  1982
# 1                     Blood Loss  2008
# 2                   Anjo do Lodo  1951
# 3                        Jaws 19  2015
# 4                 Lost in Abroad  2012
# 5  Huntress: Spirit of the Night  1995
# 6              Apartment 1303 3D  2012
# 7                    Yellow Jack  1938

# %%
titles.tail(8)
# Out:
#                                  title  year
# 244906  Anna, quel particolare piacere  1973
# 244907                             Tic  2010
# 244908               Copying Beethoven  2006
# 244909                        Sam (II)  2017
# 244910                       Her Benny  1920
# 244911                  Vermont Street  2020
# 244912             Stigma of Womanhood  2016
# 244913                 Oh Heavenly Dog  1980

# %%
h = titles.head()
h
# Out:
#                         title  year
# 0  En busca del huevo perdido  1982
# 1                  Blood Loss  2008
# 2                Anjo do Lodo  1951
# 3                     Jaws 19  2015
# 4              Lost in Abroad  2012

# %%
h['year']
# Out:
# 0    1982
# 1    2008
# 2    1951
# 3    2015
# 4    2012
# Name: year, dtype: int64

# %%
h.year
# Out:
# 0    1982
# 1    2008
# 2    1951
# 3    2015
# 4    2012
# Name: year, dtype: int64

# %%
h['year'] // 10
# Out:
# 0    198
# 1    200
# 2    195
# 3    201
# 4    201
# Name: year, dtype: int64

# %%
h['year'] // 10 * 10
# Out:
# 0    1980
# 1    2000
# 2    1950
# 3    2010
# 4    2010
# Name: year, dtype: int64

# %%
h['title']
# Out:
# 0    En busca del huevo perdido
# 1                    Blood Loss
# 2                  Anjo do Lodo
# 3                       Jaws 19
# 4                Lost in Abroad
# Name: title, dtype: object

# %%
h.year > 1985
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# Name: year, dtype: bool

# %%
h[h.year > 1985]
# Out:
#             title  year
# 1      Blood Loss  2008
# 3         Jaws 19  2015
# 4  Lost in Abroad  2012

# %%
h[h.year < 1985]
# Out:
#                         title  year
# 0  En busca del huevo perdido  1982
# 2                Anjo do Lodo  1951

# %%
h[(h.year < 1980) | (h.year >= 1990)]

# If you wnat 'and' do: &
# Out:
#             title  year
# 1      Blood Loss  2008
# 2    Anjo do Lodo  1951
# 3         Jaws 19  2015
# 4  Lost in Abroad  2012

# %%
t = titles
t[t.title == 'Macbeth']
# Out:
#           title  year
# 5840    Macbeth  1998
# 29455   Macbeth  1997
# 66782   Macbeth  2015
# 69395   Macbeth  2004
# 77844   Macbeth  1913
# 85842   Macbeth  2013
# 96271   Macbeth  2014
# 108140  Macbeth  2017
# 116936  Macbeth  2018
# 145902  Macbeth  1987
# 175154  Macbeth  2009
# 176095  Macbeth  1916
# 192819  Macbeth  2003
# 207594  Macbeth  2012
# 207758  Macbeth  1948
# 239784  Macbeth  2006

# %%
t[t.title == 'Macbeth'].sort_values('year')
# Out:
#           title  year
# 77844   Macbeth  1913
# 176095  Macbeth  1916
# 207758  Macbeth  1948
# 145902  Macbeth  1987
# 29455   Macbeth  1997
# 5840    Macbeth  1998
# 192819  Macbeth  2003
# 69395   Macbeth  2004
# 239784  Macbeth  2006
# 175154  Macbeth  2009
# 207594  Macbeth  2012
# 85842   Macbeth  2013
# 96271   Macbeth  2014
# 66782   Macbeth  2015
# 108140  Macbeth  2017
# 116936  Macbeth  2018

# %%
x = 10
x + 20
x
# Out:
# 10

# %%
h = cast.head()
h = h[h.n.notnull()]
h
# Out:
#                  title  year      name   type        character     n
# 0       Closet Monster  2015  Buffy #1  actor          Buffy 4  31.0
# 1      Suuri illusioni  1985    Homo $  actor           Guests  22.0
# 2  Battle of the Sexes  2017   $hutter  actor  Bobby Riggs Fan  10.0

# %%
h = cast.head()
h = h[h.n.isnull()]
h
# Out:
#                   title  year     name   type                character   n
# 3  Secret in Their Eyes  2015  $hutter  actor          2002 Dodger Fan NaN
# 4            Steve Jobs  2015  $hutter  actor  1988 Opera House Patron NaN

# %%
t = titles
c = cast

# %%
t[t.title == 'Hamlet']
# Out:
#          title  year
# 15005   Hamlet  1990
# 28251   Hamlet  2015
# 31739   Hamlet  1910
# 45507   Hamlet  1954
# 83780   Hamlet  1973
# 85222   Hamlet  1964
# 85679   Hamlet  1987
# 90213   Hamlet  2016
# 106995  Hamlet  2011
# 118162  Hamlet  2000
# 128187  Hamlet  1948
# 142239  Hamlet  1911
# 172269  Hamlet  1913
# 208072  Hamlet  2009
# 208870  Hamlet  1969
# 209772  Hamlet  1996
# 214106  Hamlet  1976
# 216036  Hamlet  1921
# 216743  Hamlet  2017
# 235581  Hamlet  2014

# %%
'Hamlet (II)'.startswith('Hamlet')
# Out:
# True

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244914 entries, 0 to 244913
# Data columns (total 2 columns):
# title    244914 non-null object
# year     244914 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 3.7+ MB

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3786176 entries, 0 to 3786175
# Data columns (total 6 columns):
# title        object
# year         int64
# name         object
# type         object
# character    object
# n            float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 173.3+ MB

# %%
c[c.title.str.startswith('Hamlet')]
# Out:
#                              title  year                    name     type  \
# 1731                        Hamlet  1996              Riz Abbasi    actor
# 6717     Hamlet, Prince of Denmark  1997            Ernest Abuba    actor
# 7789                        Hamlet  1921        Fritz Achterberg    actor
# 11728                       Hamlet  2009            Hayden Adams    actor
# 11729                       Hamlet  2009            Hayden Adams    actor
# 13040                     Hamlet 2  2008           Valerie Adams    actor
# 14493                       Hamlet  1913             Eric Adeney    actor
# 16148                     Hamlet 2  2008             Evan Adrian    actor
# 16771                       Hamlet  2000           Casey Affleck    actor
# 19971    Hamlet: Prince of Denmark  1989            Kabir Ahamed    actor
# 26340                  Hamlet (II)  1964          Michael Alaimo    actor
# 27209                  Hamlet (II)  2017        Dimitri Alavidze    actor
# ...
